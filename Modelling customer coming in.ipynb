# %%
import random
import numpy as np
from collections import deque

# %%
# Define constants
ARRIVAL_RATE = 20/60  # Average arrivals per second
SERVICE_RATE = (1/3)/60  # Average service time is 3 minutes, so 1/3 services in 1 min
SIMULATION_TIME = 120*60  # Total simulation time in seconds
NUM_SERVERS = 45  # Number of servers

# Initialize lists for tracking customers
customer_data = []  # Active customers
completed_customers = []  # Completed customers
cycle_call_counts = []  # Call counts per cycle

# Helper function to generate patience time T
def generate_patience_time(case):
    if case == "uniform":
        return random.uniform(0, 6)  # Uniformly distributed [0, 6] minutes
    elif case == "hyperexponential":
        if random.random() < 0.5:  # Probability 1/2
            return np.random.exponential(1)  # Mean = 1 minute
        else:
            return np.random.exponential(5)  # Mean = 5 minutes

# Helper function to generate inter-arrival times
def generate_interarrival_time():
    return np.random.exponential(1 / ARRIVAL_RATE)  # Poisson arrivals

# Helper function to generate service times
def generate_service_time():
    return np.random.exponential(1 / SERVICE_RATE)  # Exponential service times

# Simulation function
def simulate(case, simulation_time=SIMULATION_TIME, num_servers=NUM_SERVERS):
    global customer_data, completed_customers, cycle_call_counts
    customer_data = []
    completed_customers = []
    cycle_call_counts = []

    # Initialize simulation variables
    current_time = 0
    next_arrival_time = generate_interarrival_time()
    servers = [None] * num_servers  # Track busy/free servers
    queue = deque()  # Call waiting queue
    customer_id = 0
    cycle_calls = 0

    while current_time < simulation_time:
        # Check if a server is done with its current call
        for i in range(num_servers):
            if servers[i] and servers[i]['service_end_time'] <= current_time:
                completed_customers.append(servers[i]['customer'])
                servers[i] = None

        # Handle queue (update waiting times and check for abandonment)
        for customer in queue.copy():
            customer['Time left in queue'] -= 1
            if customer['Time left in queue'] <= 0:
                customer['Time left in queue'] = 0
                customer['Exit time'] = current_time
                completed_customers.append(customer)
                queue.remove(customer)

        # Assign available servers to customers in the queue
        for i in range(num_servers):
            if not servers[i] and queue:
                customer = queue.popleft()
                service_time = generate_service_time()
                customer['Exit time'] = current_time + service_time
                servers[i] = {
                    'customer': customer,
                    'service_end_time': current_time + service_time,
                }

        # Handle arrivals
        if current_time >= next_arrival_time:
            # Start a new cycle if all servers are idle and queue is empty
            if all(s is None for s in servers) and not queue:
                if cycle_calls > 0:
                    cycle_call_counts.append(cycle_calls)
                cycle_calls = 0

            # Generate a new call
            customer_id += 1
            patience_time = generate_patience_time(case)
            arrival_time = current_time
            time_left_in_queue = 60 * patience_time

            new_customer = {
                'Customer_id': customer_id,
                'Time left in queue': time_left_in_queue,
                'Arrival time': arrival_time,
                'Exit time': None,
            }
            customer_data.append(new_customer)
            queue.append(new_customer)
            cycle_calls += 1

            # Schedule next arrival
            next_arrival_time += generate_interarrival_time()

        # Increment simulation time
        current_time += 1

    # Final cycle count
    if cycle_calls > 0:
        cycle_call_counts.append(cycle_calls)

# Run simulations for both cases
simulate("uniform")
uniform_case_results = {
    "customer_data": customer_data,
    "completed_customers": completed_customers,
    "cycle_call_counts": cycle_call_counts,
}

simulate("hyperexponential")
hyperexp_case_results = {
    "customer_data": customer_data,
    "completed_customers": completed_customers,
    "cycle_call_counts": cycle_call_counts,
}

# %%
uniform_case_results["customer_data"]
# Out:
# [{'Customer_id': 1,
#   'Time left in queue': 207.95031187808206,
#   'Arrival time': 1,
#   'Exit time': 419.3480704756792},
#  {'Customer_id': 2,
#   'Time left in queue': 100.56661920519136,
#   'Arrival time': 2,
#   'Exit time': 93.10743614357325},
#  {'Customer_id': 3,
#   'Time left in queue': 256.15768697106677,
#   'Arrival time': 3,
#   'Exit time': 128.88052557391262},
#  {'Customer_id': 4,
#   'Time left in queue': 358.6056815300981,
#   'Arrival time': 4,
#   'Exit time': 110.98625416373619},
#  {'Customer_id': 5,
#   'Time left in queue': 208.81391037399518,
#   'Arrival time': 8,
#   'Exit time': 100.09961608104594},
#  {'Customer_id': 6,
#   'Time left in queue': 339.01612944579784,
#   'Arrival time': 10,
#   'Exit time': 108.82215210244786},
#  {'Customer_id': 7,
#   'Time left in queue': 353.062512747321,
#   'Arrival time': 17,
#   'Exit time': 193.144953877731},
#  {'Customer_id': 8,
#   'Time left in queue': 81.4507823838731,
#   'Arrival time': 22,
#   'Exit time': 247.67651341711982},
#  {'Customer_id': 9,
#   'Time left in queue': 337.78707639378075,
#   'Arrival time': 24,
#   'Exit time': 156.1299638024503},
#  {'Customer_id': 10,
#   'Time left in queue': 335.9400339608298,
#   'Arrival time': 25,
#   'Exit time': 287.49571079228537},
#  {'Customer_id': 11,
#   'Time left in queue': 354.19522604442534,
#   'Arrival time': 26,
#   'Exit time': 35.71296931936977},
#  {'Customer_id': 12,
#   'Time left in queue': 62.613365619048835,
#   'Arrival time': 28,
#   'Exit time': 184.18046368229128},
#  {'Customer_id': 13,
#   'Time left in queue': 94.2953328156751,
#   'Arrival time': 30,
#   'Exit time': 503.107764434663},
#  {'Customer_id': 14,
#   'Time left in queue': 69.14570767987348,
#   'Arrival time': 35,
#   'Exit time': 154.7852622781303},
#  {'Customer_id': 15,
#   'Time left in queue': 121.17782601545852,
#   'Arrival time': 42,
#   'Exit time': 155.01589058881285},
#  {'Customer_id': 16,
#   'Time left in queue': 96.82875540092866,
#   'Arrival time': 43,
#   'Exit time': 69.1137289112575},
#  {'Customer_id': 17,
#   'Time left in queue': 281.2611963284371,
#   'Arrival time': 44,
#   'Exit time': 352.7613145303721},
#  {'Customer_id': 18,
#   'Time left in queue': 160.84977910052555,
#   'Arrival time': 45,
#   'Exit time': 381.29395460076967},
#  {'Customer_id': 19,
#   'Time left in queue': 269.71005280078833,
#   'Arrival time': 46,
#   'Exit time': 182.59405344434475},
#  {'Customer_id': 20,
#   'Time left in queue': 56.719120918608596,
#   'Arrival time': 47,
#   'Exit time': 108.85683948326422},
#  {'Customer_id': 21,
#   'Time left in queue': 194.5130365479211,
#   'Arrival time': 65,
#   'Exit time': 168.6313726698787},
#  {'Customer_id': 22,
#   'Time left in queue': 104.15791677907251,
#   'Arrival time': 67,
#   'Exit time': 215.59266966910872},
#  {'Customer_id': 23,
#   'Time left in queue': 122.25559873948434,
#   'Arrival time': 70,
#   'Exit time': 73.91509553080662},
#  {'Customer_id': 24,
#   'Time left in queue': 46.245569522605635,
#   'Arrival time': 72,
#   'Exit time': 252.90561397933973},
#  {'Customer_id': 25,
#   'Time left in queue': 218.49940434013254,
#   'Arrival time': 87,
#   'Exit time': 449.57824094080524},
#  {'Customer_id': 26,
#   'Time left in queue': 6.008949802953635,
#   'Arrival time': 90,
#   'Exit time': 582.6442375329084},
#  {'Customer_id': 27,
#   'Time left in queue': 132.83416884328466,
#   'Arrival time': 91,
#   'Exit time': 116.58412594222813},
#  {'Customer_id': 28,
#   'Time left in queue': 222.02786680768466,
#   'Arrival time': 92,
#   'Exit time': 120.89094092921812},
#  {'Customer_id': 29,
#   'Time left in queue': 340.3185155952361,
#   'Arrival time': 93,
#   'Exit time': 291.8919314191355},
#  {'Customer_id': 30,
#   'Time left in queue': 267.0557145001151,
#   'Arrival time': 96,
#   'Exit time': 289.0421467453225},
#  {'Customer_id': 31,
#   'Time left in queue': 157.8704912676489,
#   'Arrival time': 102,
#   'Exit time': 117.52814286657093},
#  {'Customer_id': 32,
#   'Time left in queue': 353.70023935965054,
#   'Arrival time': 103,
#   'Exit time': 348.40721271081895},
#  {'Customer_id': 33,
#   'Time left in queue': 138.34735183105883,
#   'Arrival time': 105,
#   'Exit time': 122.06090477740011},
#  {'Customer_id': 34,
#   'Time left in queue': 270.5568303099882,
#   'Arrival time': 106,
#   'Exit time': 207.98760468149635},
#  {'Customer_id': 35,
#   'Time left in queue': 87.71917472613508,
#   'Arrival time': 107,
#   'Exit time': 698.2024702124004},
#  {'Customer_id': 36,
#   'Time left in queue': 159.28677257626384,
#   'Arrival time': 112,
#   'Exit time': 163.10140668285567},
#  {'Customer_id': 37,
#   'Time left in queue': 355.82669655799833,
#   'Arrival time': 118,
#   'Exit time': 193.87027094767626},
#  {'Customer_id': 38,
#   'Time left in queue': 273.40638212888246,
#   'Arrival time': 120,
#   'Exit time': 216.26145937942968},
#  {'Customer_id': 39,
#   'Time left in queue': 225.4043434391839,
#   'Arrival time': 121,
#   'Exit time': 224.35599268847818},
#  {'Customer_id': 40,
#   'Time left in queue': 174.31357769019345,
#   'Arrival time': 133,
#   'Exit time': 324.6765489682999},
#  {'Customer_id': 41,
#   'Time left in queue': 342.39481453306854,
#   'Arrival time': 137,
#   'Exit time': 465.17551808860816},
#  {'Customer_id': 42,
#   'Time left in queue': 113.02225437136715,
#   'Arrival time': 143,
#   'Exit time': 213.6534328575887},
#  {'Customer_id': 43,
#   'Time left in queue': 85.12200123519284,
#   'Arrival time': 148,
#   'Exit time': 265.44033897824335},
#  {'Customer_id': 44,
#   'Time left in queue': 292.11932093210123,
#   'Arrival time': 149,
#   'Exit time': 332.6189970923183},
#  {'Customer_id': 45,
#   'Time left in queue': 156.21866001469147,
#   'Arrival time': 151,
#   'Exit time': 254.7489600271005},
#  {'Customer_id': 46,
#   'Time left in queue': 196.7683674733355,
#   'Arrival time': 154,
#   'Exit time': 332.09862936658806},
#  {'Customer_id': 47,
#   'Time left in queue': 110.62660385381514,
#   'Arrival time': 157,
#   'Exit time': 193.30508459189105},
#  {'Customer_id': 48,
#   'Time left in queue': 146.4115804558267,
#   'Arrival time': 158,
#   'Exit time': 370.30833094242763},
#  {'Customer_id': 49,
#   'Time left in queue': 92.48944722550075,
#   'Arrival time': 159,
#   'Exit time': 439.9709550742626},
#  {'Customer_id': 50,
#   'Time left in queue': 122.9448533783241,
#   'Arrival time': 160,
#   'Exit time': 267.43490832601316},
#  {'Customer_id': 51,
#   'Time left in queue': 187.06789786133632,
#   'Arrival time': 167,
#   'Exit time': 298.2477734515677},
#  {'Customer_id': 52,
#   'Time left in queue': 234.14349181218412,
#   'Arrival time': 170,
#   'Exit time': 327.7918057020082},
#  {'Customer_id': 53,
#   'Time left in queue': 107.89700218428828,
#   'Arrival time': 172,
#   'Exit time': 304.91000652694015},
#  {'Customer_id': 54,
#   'Time left in queue': 55.22350382225138,
#   'Arrival time': 178,
#   'Exit time': 226.4710682158925},
#  {'Customer_id': 55,
#   'Time left in queue': 142.2671536182315,
#   'Arrival time': 184,
#   'Exit time': 207.6776512935239},
#  {'Customer_id': 56,
#   'Time left in queue': 66.74453909977655,
#   'Arrival time': 185,
#   'Exit time': 240.40960509112037},
#  {'Customer_id': 57,
#   'Time left in queue': 343.3502733977298,
#   'Arrival time': 186,
#   'Exit time': 259.95404611476306},
#  {'Customer_id': 58,
#   'Time left in queue': 56.08853833168824,
#   'Arrival time': 187,
#   'Exit time': 239.4167592382442},
#  {'Customer_id': 59,
#   'Time left in queue': 162.52646413467477,
#   'Arrival time': 188,
#   'Exit time': 726.8669728625725},
#  {'Customer_id': 60,
#   'Time left in queue': 301.1175421733026,
#   'Arrival time': 189,
#   'Exit time': 263.66280891459115},
#  {'Customer_id': 61,
#   'Time left in queue': 0,
#   'Arrival time': 190,
#   'Exit time': 191},
#  {'Customer_id': 62,
#   'Time left in queue': 320.81949530406024,
#   'Arrival time': 191,
#   'Exit time': 456.85231910260296},
#  {'Customer_id': 63,
#   'Time left in queue': 178.56164221798255,
#   'Arrival time': 192,
#   'Exit time': 299.328197997831},
#  {'Customer_id': 64,
#   'Time left in queue': 22.202085153764124,
#   'Arrival time': 196,
#   'Exit time': 321.5689209112621},
#  {'Customer_id': 65,
#   'Time left in queue': 272.20474668427727,
#   'Arrival time': 197,
#   'Exit time': 426.7333054861931},
#  {'Customer_id': 66,
#   'Time left in queue': 186.53025047767656,
#   'Arrival time': 198,
#   'Exit time': 297.3788058968892},
#  {'Customer_id': 67,
#   'Time left in queue': 131.7056488723551,
#   'Arrival time': 199,
#   'Exit time': 389.0892795075607},
#  {'Customer_id': 68,
#   'Time left in queue': 186.45108862137795,
#   'Arrival time': 200,
#   'Exit time': 476.060871305286},
#  {'Customer_id': 69,
#   'Time left in queue': 145.32812083015978,
#   'Arrival time': 202,
#   'Exit time': 227.273945354755},
#  {'Customer_id': 70,
#   'Time left in queue': 100.95242881718691,
#   'Arrival time': 205,
#   'Exit time': 669.9537639339621},
#  {'Customer_id': 71,
#   'Time left in queue': 185.44027737799266,
#   'Arrival time': 207,
#   'Exit time': 279.67278897929907},
#  {'Customer_id': 72,
#   'Time left in queue': 234.97010410077436,
#   'Arrival time': 209,
#   'Exit time': 219.90128141146874},
#  {'Customer_id': 73,
#   'Time left in queue': 149.23723770139193,
#   'Arrival time': 214,
#   'Exit time': 701.017687870303},
#  {'Customer_id': 74,
#   'Time left in queue': 233.69658072678857,
#   'Arrival time': 220,
#   'Exit time': 227.5370983223709},
#  {'Customer_id': 75,
#   'Time left in queue': 164.1325562084941,
#   'Arrival time': 226,
#   'Exit time': 324.73797068151976},
#  {'Customer_id': 76,
#   'Time left in queue': 328.09956064164095,
#   'Arrival time': 227,
#   'Exit time': 400.29553073137487},
#  {'Customer_id': 77,
#   'Time left in queue': 337.00127272852706,
#   'Arrival time': 228,
#   'Exit time': 420.2623828505299},
#  {'Customer_id': 78,
#   'Time left in queue': 353.2669083322549,
#   'Arrival time': 230,
#   'Exit time': 462.54583757489223},
#  {'Customer_id': 79,
#   'Time left in queue': 43.051563791246906,
#   'Arrival time': 232,
#   'Exit time': 267.5439173344799},
#  {'Customer_id': 80,
#   'Time left in queue': 63.52931009220377,
#   'Arrival time': 234,
#   'Exit time': 285.86546989087316},
#  {'Customer_id': 81,
#   'Time left in queue': 17.197842428929025,
#   'Arrival time': 235,
#   'Exit time': 245.8135521248475},
#  {'Customer_id': 82,
#   'Time left in queue': 319.00453050077397,
#   'Arrival time': 238,
#   'Exit time': 339.7264837111471},
#  {'Customer_id': 83,
#   'Time left in queue': 347.1704428695063,
#   'Arrival time': 239,
#   'Exit time': 273.1577239591185},
#  {'Customer_id': 84,
#   'Time left in queue': 104.43479376920747,
#   'Arrival time': 242,
#   'Exit time': 474.54091091151975},
#  {'Customer_id': 85,
#   'Time left in queue': 97.99528978998659,
#   'Arrival time': 243,
#   'Exit time': 275.521335676853},
#  {'Customer_id': 86,
#   'Time left in queue': 100.44142486553986,
#   'Arrival time': 251,
#   'Exit time': 387.0343809400699},
#  {'Customer_id': 87,
#   'Time left in queue': 150.27126746912893,
#   'Arrival time': 256,
#   'Exit time': 273.3857119593697},
#  {'Customer_id': 88,
#   'Time left in queue': 21.55498738465916,
#   'Arrival time': 257,
#   'Exit time': 549.1255052686402},
#  {'Customer_id': 89,
#   'Time left in queue': 222.66011374989412,
#   'Arrival time': 258,
#   'Exit time': 737.467691670735},
#  {'Customer_id': 90,
#   'Time left in queue': 336.3494438466897,
#   'Arrival time': 259,
#   'Exit time': 583.1583465994104},
#  {'Customer_id': 91,
#   'Time left in queue': 82.06239794604116,
#   'Arrival time': 263,
#   'Exit time': 274.2745966154099},
#  {'Customer_id': 92,
#   'Time left in queue': 308.2920678602934,
#   'Arrival time': 265,
#   'Exit time': 420.5015948196179},
#  {'Customer_id': 93,
#   'Time left in queue': 297.9509568257136,
#   'Arrival time': 267,
#   'Exit time': 330.50135794477325},
#  {'Customer_id': 94,
#   'Time left in queue': 300.9108760087153,
#   'Arrival time': 270,
#   'Exit time': 359.0680125074071},
#  {'Customer_id': 95,
#   'Time left in queue': 243.02131879014476,
#   'Arrival time': 272,
#   'Exit time': 376.89001594836725},
#  {'Customer_id': 96,
#   'Time left in queue': 265.47969254766883,
#   'Arrival time': 273,
#   'Exit time': 631.9444007965906},
#  {'Customer_id': 97,
#   'Time left in queue': 134.39948715812332,
#   'Arrival time': 274,
#   'Exit time': 1043.667832194695},
#  {'Customer_id': 98,
#   'Time left in queue': 278.1106187914959,
#   'Arrival time': 280,
#   'Exit time': 331.76918748284515},
#  {'Customer_id': 99,
#   'Time left in queue': 47.637867630919324,
#   'Arrival time': 282,
#   'Exit time': 317.65069668326714},
#  {'Customer_id': 100,
#   'Time left in queue': 191.21915317907218,
#   'Arrival time': 286,
#   'Exit time': 565.8765559065087},
#  {'Customer_id': 101,
#   'Time left in queue': 212.95787934119028,
#   'Arrival time': 287,
#   'Exit time': 363.2686782631251},
#  {'Customer_id': 102,
#   'Time left in queue': 184.88695056291883,
#   'Arrival time': 290,
#   'Exit time': 381.0177901703516},
#  {'Customer_id': 103,
#   'Time left in queue': 317.9789024516073,
#   'Arrival time': 291,
#   'Exit time': 971.2527784439519},
#  {'Customer_id': 104,
#   'Time left in queue': 301.75133673483435,
#   'Arrival time': 292,
#   'Exit time': 511.2254102717271},
#  {'Customer_id': 105,
#   'Time left in queue': 228.81243575857573,
#   'Arrival time': 296,
#   'Exit time': 549.2384028882805},
#  {'Customer_id': 106,
#   'Time left in queue': 313.9433247929043,
#   'Arrival time': 303,
#   'Exit time': 373.39843428201175},
#  {'Customer_id': 107,
#   'Time left in queue': 180.7654800415545,
#   'Arrival time': 304,
#   'Exit time': 430.2342663354814},
#  {'Customer_id': 108,
#   'Time left in queue': 146.88683409392746,
#   'Arrival time': 305,
#   'Exit time': 1163.565091825525},
#  {'Customer_id': 109,
#   'Time left in queue': 147.7744012531364,
#   'Arrival time': 306,
#   'Exit time': 567.0570216555857},
#  {'Customer_id': 110,
#   'Time left in queue': 65.78892332727224,
#   'Arrival time': 307,
#   'Exit time': 393.0129375689903},
#  {'Customer_id': 111,
#   'Time left in queue': 80.05659440839642,
#   'Arrival time': 308,
#   'Exit time': 560.1011252720618},
#  {'Customer_id': 112,
#   'Time left in queue': 121.96360666633208,
#   'Arrival time': 310,
#   'Exit time': 335.89296914526955},
#  {'Customer_id': 113,
#   'Time left in queue': 80.76236048370447,
#   'Arrival time': 311,
#   'Exit time': 370.9101541568043},
#  {'Customer_id': 114,
#   'Time left in queue': 19.33395273591598,
#   'Arrival time': 313,
#   'Exit time': 575.1037565848848},
#  {'Customer_id': 115,
#   'Time left in queue': 283.51616987355607,
#   'Arrival time': 314,
#   'Exit time': 430.56418314676677},
#  {'Customer_id': 116,
#   'Time left in queue': 68.89252296406924,
#   'Arrival time': 315,
#   'Exit time': 1602.0849072173803},
#  {'Customer_id': 117,
#   'Time left in queue': 0,
#   'Arrival time': 318,
#   'Exit time': 360},
#  {'Customer_id': 118,
#   'Time left in queue': 298.4682790681504,
#   'Arrival time': 319,
#   'Exit time': 445.43101182969116},
#  {'Customer_id': 119,
#   'Time left in queue': 169.62576330170495,
#   'Arrival time': 322,
#   'Exit time': 502.24693981283536},
#  {'Customer_id': 120,
#   'Time left in queue': 257.15634252306813,
#   'Arrival time': 329,
#   'Exit time': 828.6155434649407},
#  {'Customer_id': 121,
#   'Time left in queue': 20.31556693913884,
#   'Arrival time': 340,
#   'Exit time': 438.92037801972265},
#  {'Customer_id': 122,
#   'Time left in queue': 129.2595973424492,
#   'Arrival time': 350,
#   'Exit time': 475.411967800343},
#  {'Customer_id': 123,
#   'Time left in queue': 196.04832310760958,
#   'Arrival time': 351,
#   'Exit time': 759.1892130305582},
#  {'Customer_id': 124,
#   'Time left in queue': 20.541253776215456,
#   'Arrival time': 354,
#   'Exit time': 414.83958135473523},
#  {'Customer_id': 125,
#   'Time left in queue': 94.70177757540725,
#   'Arrival time': 355,
#   'Exit time': 750.027521035538},
#  {'Customer_id': 126,
#   'Time left in queue': 262.58218862510734,
#   'Arrival time': 356,
#   'Exit time': 451.91918971195145},
#  {'Customer_id': 127,
#   'Time left in queue': 284.8257420545104,
#   'Arrival time': 358,
#   'Exit time': 778.9652530914998},
#  {'Customer_id': 128,
#   'Time left in queue': 105.72690467978441,
#   'Arrival time': 369,
#   'Exit time': 505.23565937554037},
#  {'Customer_id': 129,
#   'Time left in queue': 0,
#   'Arrival time': 370,
#   'Exit time': 392},
#  {'Customer_id': 130,
#   'Time left in queue': 190.9675159222903,
#   'Arrival time': 373,
#   'Exit time': 565.7499378369016},
#  {'Customer_id': 131,
#   'Time left in queue': 216.6024241437915,
#   'Arrival time': 376,
#   'Exit time': 579.3912735592519},
#  {'Customer_id': 132,
#   'Time left in queue': 226.12646564040807,
#   'Arrival time': 378,
#   'Exit time': 445.44760535619304},
#  {'Customer_id': 133,
#   'Time left in queue': 0,
#   'Arrival time': 389,
#   'Exit time': 401},
#  {'Customer_id': 134,
#   'Time left in queue': 241.1605358471935,
#   'Arrival time': 393,
#   'Exit time': 476.1410891375092},
#  {'Customer_id': 135,
#   'Time left in queue': 160.73736601751915,
#   'Arrival time': 395,
#   'Exit time': 849.8378739310049},
#  {'Customer_id': 136,
#   'Time left in queue': 232.78513271605954,
#   'Arrival time': 397,
#   'Exit time': 440.3102593991155},
#  {'Customer_id': 137,
#   'Time left in queue': 102.83355080846908,
#   'Arrival time': 398,
#   'Exit time': 718.2829835157497},
#  {'Customer_id': 138,
#   'Time left in queue': 313.80760977339685,
#   'Arrival time': 399,
#   'Exit time': 802.940950698553},
#  {'Customer_id': 139,
#   'Time left in queue': 147.76460397014193,
#   'Arrival time': 402,
#   'Exit time': 489.48048049584025},
#  {'Customer_id': 140,
#   'Time left in queue': 0,
#   'Arrival time': 403,
#   'Exit time': 416},
#  {'Customer_id': 141,
#   'Time left in queue': 0,
#   'Arrival time': 404,
#   'Exit time': 424},
#  {'Customer_id': 142,
#   'Time left in queue': 14.636999616687781,
#   'Arrival time': 405,
#   'Exit time': 508.23536510147574},
#  {'Customer_id': 143,
#   'Time left in queue': 132.91973985774914,
#   'Arrival time': 406,
#   'Exit time': 557.8840883498997},
#  {'Customer_id': 144,
#   'Time left in queue': 129.99700034233692,
#   'Arrival time': 410,
#   'Exit time': 695.3413066139885},
#  {'Customer_id': 145,
#   'Time left in queue': 299.0616661438109,
#   'Arrival time': 411,
#   'Exit time': 465.8068773328663},
#  {'Customer_id': 146,
#   'Time left in queue': 0,
#   'Arrival time': 417,
#   'Exit time': 433},
#  {'Customer_id': 147,
#   'Time left in queue': 0,
#   'Arrival time': 422,
#   'Exit time': 431},
#  {'Customer_id': 148,
#   'Time left in queue': 2.47446515806325,
#   'Arrival time': 428,
#   'Exit time': 484.720553950668},
#  {'Customer_id': 149,
#   'Time left in queue': 5.311526784281519,
#   'Arrival time': 435,
#   'Exit time': 501.5653723189981},
#  {'Customer_id': 150,
#   'Time left in queue': 263.4948107627277,
#   'Arrival time': 436,
#   'Exit time': 530.5904338924803},
#  {'Customer_id': 151,
#   'Time left in queue': 98.14143714132882,
#   'Arrival time': 438,
#   'Exit time': 617.955540210845},
#  {'Customer_id': 152,
#   'Time left in queue': 150.31694395230875,
#   'Arrival time': 439,
#   'Exit time': 792.8477368278491},
#  {'Customer_id': 153,
#   'Time left in queue': 6.19080915414046,
#   'Arrival time': 440,
#   'Exit time': 586.0981595127968},
#  {'Customer_id': 154,
#   'Time left in queue': 60.137949336738345,
#   'Arrival time': 441,
#   'Exit time': 606.4278771778222},
#  {'Customer_id': 155,
#   'Time left in queue': 35.68623061765159,
#   'Arrival time': 443,
#   'Exit time': 575.5155622372129},
#  {'Customer_id': 156,
#   'Time left in queue': 131.550184811487,
#   'Arrival time': 444,
#   'Exit time': 522.2064013757494},
#  {'Customer_id': 157,
#   'Time left in queue': 7.838057900440845,
#   'Arrival time': 447,
#   'Exit time': 580.2463210799671},
#  {'Customer_id': 158,
#   'Time left in queue': 0,
#   'Arrival time': 450,
#   'Exit time': 475},
#  {'Customer_id': 159,
#   'Time left in queue': 157.44238228304306,
#   'Arrival time': 452,
#   'Exit time': 693.9524563154077},
#  {'Customer_id': 160,
#   'Time left in queue': 132.40416068522228,
#   'Arrival time': 454,
#   'Exit time': 590.9116163894734},
#  {'Customer_id': 161,
#   'Time left in queue': 160.23228737880507,
#   'Arrival time': 456,
#   'Exit time': 1224.2383663945316},
#  {'Customer_id': 162,
#   'Time left in queue': 274.39415696821334,
#   'Arrival time': 457,
#   'Exit time': 530.3997852365941},
#  {'Customer_id': 163,
#   'Time left in queue': 116.26037134572451,
#   'Arrival time': 463,
#   'Exit time': 764.497381804},
#  {'Customer_id': 164,
#   'Time left in queue': 64.84182693161925,
#   'Arrival time': 468,
#   'Exit time': 812.9983501104045},
#  {'Customer_id': 165,
#   'Time left in queue': 298.0649395616155,
#   'Arrival time': 472,
#   'Exit time': 790.7339494422533},
#  {'Customer_id': 166,
#   'Time left in queue': 280.8872011460207,
#   'Arrival time': 473,
#   'Exit time': 752.714943381866},
#  {'Customer_id': 167,
#   'Time left in queue': 265.2501145587252,
#   'Arrival time': 474,
#   'Exit time': 1580.8015108273535},
#  {'Customer_id': 168,
#   'Time left in queue': 45.73162407709117,
#   'Arrival time': 476,
#   'Exit time': 1478.10276971388},
#  {'Customer_id': 169,
#   'Time left in queue': 102.80399343192332,
#   'Arrival time': 477,
#   'Exit time': 671.1366835253657},
#  {'Customer_id': 170,
#   'Time left in queue': 0,
#   'Arrival time': 478,
#   'Exit time': 501},
#  {'Customer_id': 171,
#   'Time left in queue': 0,
#   'Arrival time': 479,
#   'Exit time': 533},
#  {'Customer_id': 172,
#   'Time left in queue': 93.7394790701145,
#   'Arrival time': 480,
#   'Exit time': 591.9810169931393},
#  {'Customer_id': 173,
#   'Time left in queue': 21.562373124899906,
#   'Arrival time': 483,
#   'Exit time': 665.8212413716145},
#  {'Customer_id': 174,
#   'Time left in queue': 19.8681596115116,
#   'Arrival time': 484,
#   'Exit time': 680.7756960804361},
#  {'Customer_id': 175,
#   'Time left in queue': 191.86088441754248,
#   'Arrival time': 486,
#   'Exit time': 654.2816746491075},
#  {'Customer_id': 176,
#   'Time left in queue': 0,
#   'Arrival time': 490,
#   'Exit time': 506},
#  {'Customer_id': 177,
#   'Time left in queue': 0,
#   'Arrival time': 494,
#   'Exit time': 535},
#  {'Customer_id': 178,
#   'Time left in queue': 123.71180476224555,
#   'Arrival time': 503,
#   'Exit time': 586.227999755011},
#  {'Customer_id': 179,
#   'Time left in queue': 0,
#   'Arrival time': 509,
#   'Exit time': 513},
#  {'Customer_id': 180,
#   'Time left in queue': 170.933620519796,
#   'Arrival time': 513,
#   'Exit time': 587.3435202325537},
#  {'Customer_id': 181,
#   'Time left in queue': 158.9828222333483,
#   'Arrival time': 521,
#   'Exit time': 782.4765983764436},
#  {'Customer_id': 182,
#   'Time left in queue': 12.249279291432345,
#   'Arrival time': 524,
#   'Exit time': 655.9234169083129},
#  {'Customer_id': 183,
#   'Time left in queue': 0,
#   'Arrival time': 525,
#   'Exit time': 537},
#  {'Customer_id': 184,
#   'Time left in queue': 300.36905557314265,
#   'Arrival time': 534,
#   'Exit time': 579.2102261803376},
#  {'Customer_id': 185,
#   'Time left in queue': 148.93502585077974,
#   'Arrival time': 535,
#   'Exit time': 607.7812816757953},
#  {'Customer_id': 186,
#   'Time left in queue': 258.92903979421527,
#   'Arrival time': 539,
#   'Exit time': 802.4982398485283},
#  {'Customer_id': 187,
#   'Time left in queue': 0,
#   'Arrival time': 542,
#   'Exit time': 566},
#  {'Customer_id': 188,
#   'Time left in queue': 256.6430468631154,
#   'Arrival time': 543,
#   'Exit time': 607.0499255693875},
#  {'Customer_id': 189,
#   'Time left in queue': 200.91216936136294,
#   'Arrival time': 547,
#   'Exit time': 616.3333572742675},
#  {'Customer_id': 190,
#   'Time left in queue': 171.65521576365643,
#   'Arrival time': 552,
#   'Exit time': 714.5550278126941},
#  {'Customer_id': 191,
#   'Time left in queue': 314.30428795377674,
#   'Arrival time': 555,
#   'Exit time': 888.1128035280981},
#  {'Customer_id': 192,
#   'Time left in queue': 92.19365266240719,
#   'Arrival time': 556,
#   'Exit time': 832.2160794716604},
#  {'Customer_id': 193,
#   'Time left in queue': 187.2218825901339,
#   'Arrival time': 557,
#   'Exit time': 824.0958427646503},
#  {'Customer_id': 194,
#   'Time left in queue': 319.90567511437825,
#   'Arrival time': 569,
#   'Exit time': 749.9756298681522},
#  {'Customer_id': 195,
#   'Time left in queue': 290.5533015450541,
#   'Arrival time': 574,
#   'Exit time': 707.8961667855992},
#  {'Customer_id': 196,
#   'Time left in queue': 105.73159565494362,
#   'Arrival time': 575,
#   'Exit time': 732.890295306194},
#  {'Customer_id': 197,
#   'Time left in queue': 68.49165670537528,
#   'Arrival time': 578,
#   'Exit time': 632.1501998586479},
#  {'Customer_id': 198,
#   'Time left in queue': 84.50858169997105,
#   'Arrival time': 580,
#   'Exit time': 619.4639767340357},
#  {'Customer_id': 199,
#   'Time left in queue': 1.2383133884721467,
#   'Arrival time': 588,
#   'Exit time': 641.1674943071729},
#  {'Customer_id': 200,
#   'Time left in queue': 99.07507689189114,
#   'Arrival time': 591,
#   'Exit time': 800.5942998908275},
#  {'Customer_id': 201,
#   'Time left in queue': 228.59650907954557,
#   'Arrival time': 593,
#   'Exit time': 770.1722795332256},
#  {'Customer_id': 202,
#   'Time left in queue': 113.39942245237637,
#   'Arrival time': 594,
#   'Exit time': 658.8880650857975},
#  {'Customer_id': 203,
#   'Time left in queue': 102.44276426130855,
#   'Arrival time': 596,
#   'Exit time': 1075.6682824013694},
#  {'Customer_id': 204,
#   'Time left in queue': 173.30677235669577,
#   'Arrival time': 599,
#   'Exit time': 690.8008567720321},
#  {'Customer_id': 205,
#   'Time left in queue': 230.96618382600724,
#   'Arrival time': 607,
#   'Exit time': 731.8773137310925},
#  {'Customer_id': 206,
#   'Time left in queue': 114.60875927146742,
#   'Arrival time': 609,
#   'Exit time': 677.5174235125189},
#  {'Customer_id': 207,
#   'Time left in queue': 256.2710101694572,
#   'Arrival time': 610,
#   'Exit time': 697.5490113972903},
#  {'Customer_id': 208,
#   'Time left in queue': 195.29385464426042,
#   'Arrival time': 615,
#   'Exit time': 754.3737942833661},
#  {'Customer_id': 209,
#   'Time left in queue': 295.76540214412984,
#   'Arrival time': 617,
#   'Exit time': 761.1017614107202},
#  {'Customer_id': 210,
#   'Time left in queue': 120.51357403435105,
#   'Arrival time': 622,
#   'Exit time': 714.0451991331912},
#  {'Customer_id': 211,
#   'Time left in queue': 53.540469935079614,
#   'Arrival time': 625,
#   'Exit time': 762.7912537571094},
#  {'Customer_id': 212,
#   'Time left in queue': 26.639332353066294,
#   'Arrival time': 628,
#   'Exit time': 683.438435364085},
#  {'Customer_id': 213,
#   'Time left in queue': 184.01084265622617,
#   'Arrival time': 629,
#   'Exit time': 878.1635312049547},
#  {'Customer_id': 214,
#   'Time left in queue': 119.60200742937366,
#   'Arrival time': 631,
#   'Exit time': 1011.4975846363561},
#  {'Customer_id': 215,
#   'Time left in queue': 189.37154212579756,
#   'Arrival time': 632,
#   'Exit time': 866.9719359743806},
#  {'Customer_id': 216,
#   'Time left in queue': 192.16401051503482,
#   'Arrival time': 633,
#   'Exit time': 1442.3750233793335},
#  {'Customer_id': 217,
#   'Time left in queue': 0,
#   'Arrival time': 634,
#   'Exit time': 674},
#  {'Customer_id': 218,
#   'Time left in queue': 0,
#   'Arrival time': 636,
#   'Exit time': 644},
#  {'Customer_id': 219,
#   'Time left in queue': 164.3520170049729,
#   'Arrival time': 637,
#   'Exit time': 921.1360477368152},
#  {'Customer_id': 220,
#   'Time left in queue': 283.1944445545877,
#   'Arrival time': 638,
#   'Exit time': 764.6273294691532},
#  {'Customer_id': 221,
#   'Time left in queue': 201.96614056191947,
#   'Arrival time': 639,
#   'Exit time': 890.1669962976222},
#  {'Customer_id': 222,
#   'Time left in queue': 170.84735840981543,
#   'Arrival time': 642,
#   'Exit time': 763.2618357498782},
#  {'Customer_id': 223,
#   'Time left in queue': 187.6544035188778,
#   'Arrival time': 645,
#   'Exit time': 859.2620143397992},
#  {'Customer_id': 224,
#   'Time left in queue': 0,
#   'Arrival time': 650,
#   'Exit time': 713},
#  {'Customer_id': 225,
#   'Time left in queue': 213.5702708481794,
#   'Arrival time': 652,
#   'Exit time': 721.7569377839799},
#  {'Customer_id': 226,
#   'Time left in queue': 118.8685961698842,
#   'Arrival time': 653,
#   'Exit time': 729.9445803954275},
#  {'Customer_id': 227,
#   'Time left in queue': 46.88007565857589,
#   'Arrival time': 654,
#   'Exit time': 724.2340889503804},
#  {'Customer_id': 228,
#   'Time left in queue': 98.36348192553436,
#   'Arrival time': 655,
#   'Exit time': 1101.1448915456683},
#  {'Customer_id': 229,
#   'Time left in queue': 185.22030859814146,
#   'Arrival time': 656,
#   'Exit time': 1038.6995631820596},
#  {'Customer_id': 230,
#   'Time left in queue': 0,
#   'Arrival time': 657,
#   'Exit time': 699},
#  {'Customer_id': 231,
#   'Time left in queue': 0,
#   'Arrival time': 658,
#   'Exit time': 674},
#  {'Customer_id': 232,
#   'Time left in queue': 106.45343196730727,
#   'Arrival time': 659,
#   'Exit time': 1152.670840285337},
#  {'Customer_id': 233,
#   'Time left in queue': 202.9943409350215,
#   'Arrival time': 662,
#   'Exit time': 757.6113479266008},
#  {'Customer_id': 234,
#   'Time left in queue': 129.63082913665437,
#   'Arrival time': 666,
#   'Exit time': 791.9879762145239},
#  {'Customer_id': 235,
#   'Time left in queue': 24.938079440562078,
#   'Arrival time': 670,
#   'Exit time': 973.5393228998223},
#  {'Customer_id': 236,
#   'Time left in queue': 32.5422564614005,
#   'Arrival time': 676,
#   'Exit time': 804.5102095960398},
#  {'Customer_id': 237,
#   'Time left in queue': 0,
#   'Arrival time': 677,
#   'Exit time': 710},
#  {'Customer_id': 238,
#   'Time left in queue': 189.48907067182125,
#   'Arrival time': 683,
#   'Exit time': 1036.6638491775375},
#  {'Customer_id': 239,
#   'Time left in queue': 0,
#   'Arrival time': 685,
#   'Exit time': 695},
#  {'Customer_id': 240,
#   'Time left in queue': 212.5245610330564,
#   'Arrival time': 688,
#   'Exit time': 937.8492149808495},
#  {'Customer_id': 241,
#   'Time left in queue': 194.93697467025243,
#   'Arrival time': 689,
#   'Exit time': 1251.892897426585},
#  {'Customer_id': 242,
#   'Time left in queue': 52.959100251296164,
#   'Arrival time': 700,
#   'Exit time': 1184.678580255505},
#  {'Customer_id': 243,
#   'Time left in queue': 144.1139903595389,
#   'Arrival time': 701,
#   'Exit time': 764.3798341051115},
#  {'Customer_id': 244,
#   'Time left in queue': 123.86871476372133,
#   'Arrival time': 702,
#   'Exit time': 947.3526121492259},
#  {'Customer_id': 245,
#   'Time left in queue': 0,
#   'Arrival time': 703,
#   'Exit time': 756},
#  {'Customer_id': 246,
#   'Time left in queue': 45.05215942775621,
#   'Arrival time': 704,
#   'Exit time': 1071.3701455749033},
#  {'Customer_id': 247,
#   'Time left in queue': 0,
#   'Arrival time': 708,
#   'Exit time': 757},
#  {'Customer_id': 248,
#   'Time left in queue': 83.57921858044674,
#   'Arrival time': 710,
#   'Exit time': 861.256481125157},
#  {'Customer_id': 249,
#   'Time left in queue': 53.1474495208775,
#   'Arrival time': 712,
#   'Exit time': 807.7715018975391},
#  {'Customer_id': 250,
#   'Time left in queue': 59.43923360002009,
#   'Arrival time': 714,
#   'Exit time': 946.3895110376509},
#  {'Customer_id': 251,
#   'Time left in queue': 298.52110715279036,
#   'Arrival time': 719,
#   'Exit time': 1002.0968937211458},
#  {'Customer_id': 252,
#   'Time left in queue': 266.6606713795235,
#   'Arrival time': 720,
#   'Exit time': 904.6189682420195},
#  {'Customer_id': 253,
#   'Time left in queue': 270.2511540474755,
#   'Arrival time': 729,
#   'Exit time': 780.6007329249628},
#  {'Customer_id': 254,
#   'Time left in queue': 240.49517291585835,
#   'Arrival time': 730,
#   'Exit time': 1382.415387801505},
#  {'Customer_id': 255,
#   'Time left in queue': 42.81825495489747,
#   'Arrival time': 731,
#   'Exit time': 801.5529595495774},
#  {'Customer_id': 256,
#   'Time left in queue': 68.02430321972014,
#   'Arrival time': 736,
#   'Exit time': 1014.9345220111354},
#  {'Customer_id': 257,
#   'Time left in queue': 238.10590478992629,
#   'Arrival time': 745,
#   'Exit time': 1338.5166067925097},
#  {'Customer_id': 258,
#   'Time left in queue': 52.270149625732145,
#   'Arrival time': 748,
#   'Exit time': 897.624322680452},
#  {'Customer_id': 259,
#   'Time left in queue': 126.42625704630737,
#   'Arrival time': 753,
#   'Exit time': 944.8930655200462},
#  {'Customer_id': 260,
#   'Time left in queue': 196.6420203369391,
#   'Arrival time': 755,
#   'Exit time': 884.9006647458841},
#  {'Customer_id': 261,
#   'Time left in queue': 252.96042747268064,
#   'Arrival time': 756,
#   'Exit time': 814.3584714648418},
#  {'Customer_id': 262,
#   'Time left in queue': 192.3985364042584,
#   'Arrival time': 762,
#   'Exit time': 1063.1226335027447},
#  {'Customer_id': 263,
#   'Time left in queue': 310.03332063900626,
#   'Arrival time': 764,
#   'Exit time': 1029.4336628138856},
#  {'Customer_id': 264,
#   'Time left in queue': 63.309351319017765,
#   'Arrival time': 765,
#   'Exit time': 892.0681624230738},
#  {'Customer_id': 265,
#   'Time left in queue': 228.74622175016128,
#   'Arrival time': 770,
#   'Exit time': 827.6498285633332},
#  {'Customer_id': 266,
#   'Time left in queue': 149.52232127480747,
#   'Arrival time': 773,
#   'Exit time': 831.9134592868177},
#  {'Customer_id': 267,
#   'Time left in queue': 240.16271868509045,
#   'Arrival time': 774,
#   'Exit time': 977.1512204580137},
#  {'Customer_id': 268,
#   'Time left in queue': 0,
#   'Arrival time': 776,
#   'Exit time': 806},
#  {'Customer_id': 269,
#   'Time left in queue': 184.3498221791573,
#   'Arrival time': 777,
#   'Exit time': 992.4465007466953},
#  {'Customer_id': 270,
#   'Time left in queue': 246.3758140657348,
#   'Arrival time': 779,
#   'Exit time': 952.3409008394393},
#  {'Customer_id': 271,
#   'Time left in queue': 0,
#   'Arrival time': 798,
#   'Exit time': 818},
#  {'Customer_id': 272,
#   'Time left in queue': 296.1116991230082,
#   'Arrival time': 801,
#   'Exit time': 1144.961685966735},
#  {'Customer_id': 273,
#   'Time left in queue': 9.195731827989384,
#   'Arrival time': 802,
#   'Exit time': 1091.9937358221982},
#  {'Customer_id': 274,
#   'Time left in queue': 100.4821949814177,
#   'Arrival time': 803,
#   'Exit time': 950.3863418791927},
#  {'Customer_id': 275,
#   'Time left in queue': 183.06939851620533,
#   'Arrival time': 804,
#   'Exit time': 1240.2015018499383},
#  {'Customer_id': 276,
#   'Time left in queue': 269.80810100220845,
#   'Arrival time': 806,
#   'Exit time': 1015.2712569104727},
#  {'Customer_id': 277,
#   'Time left in queue': 0,
#   'Arrival time': 807,
#   'Exit time': 861},
#  {'Customer_id': 278,
#   'Time left in queue': 92.25576563273435,
#   'Arrival time': 808,
#   'Exit time': 1037.9492111409759},
#  {'Customer_id': 279,
#   'Time left in queue': 216.79485269718032,
#   'Arrival time': 810,
#   'Exit time': 973.6708697456091},
#  {'Customer_id': 280,
#   'Time left in queue': 40.98083662841101,
#   'Arrival time': 811,
#   'Exit time': 954.5180998821354},
#  {'Customer_id': 281,
#   'Time left in queue': 246.9215686808251,
#   'Arrival time': 814,
#   'Exit time': 920.8769737701308},
#  {'Customer_id': 282,
#   'Time left in queue': 240.96899702997996,
#   'Arrival time': 817,
#   'Exit time': 1218.4142861949456},
#  {'Customer_id': 283,
#   'Time left in queue': 0,
#   'Arrival time': 820,
#   'Exit time': 872},
#  {'Customer_id': 284,
#   'Time left in queue': 71.36927739202659,
#   'Arrival time': 822,
#   'Exit time': 982.0200358731322},
#  {'Customer_id': 285,
#   'Time left in queue': 0,
#   'Arrival time': 826,
#   'Exit time': 894},
#  {'Customer_id': 286,
#   'Time left in queue': 140.0160333797205,
#   'Arrival time': 829,
#   'Exit time': 933.2304236807851},
#  {'Customer_id': 287,
#   'Time left in queue': 7.999877947111713,
#   'Arrival time': 833,
#   'Exit time': 938.8497588501676},
#  {'Customer_id': 288,
#   'Time left in queue': 0,
#   'Arrival time': 837,
#   'Exit time': 921},
#  {'Customer_id': 289,
#   'Time left in queue': 256.6442805509087,
#   'Arrival time': 848,
#   'Exit time': 1102.292999539095},
#  {'Customer_id': 290,
#   'Time left in queue': 25.54204845851045,
#   'Arrival time': 849,
#   'Exit time': 1066.3677134741456},
#  {'Customer_id': 291,
#   'Time left in queue': 80.17750714969026,
#   'Arrival time': 851,
#   'Exit time': 955.4290815190463},
#  {'Customer_id': 292,
#   'Time left in queue': 13.246081546648554,
#   'Arrival time': 859,
#   'Exit time': 1172.7744830456857},
#  {'Customer_id': 293,
#   'Time left in queue': 155.0098628696661,
#   'Arrival time': 860,
#   'Exit time': 1103.1106403971944},
#  {'Customer_id': 294,
#   'Time left in queue': 166.23096340427142,
#   'Arrival time': 861,
#   'Exit time': 1312.1449390101711},
#  {'Customer_id': 295,
#   'Time left in queue': 87.02819280385398,
#   'Arrival time': 870,
#   'Exit time': 1107.7108891259957},
#  {'Customer_id': 296,
#   'Time left in queue': 167.477780982272,
#   'Arrival time': 872,
#   'Exit time': 1396.68936303236},
#  {'Customer_id': 297,
#   'Time left in queue': 261.0906612125513,
#   'Arrival time': 873,
#   'Exit time': 1019.5631946474867},
#  {'Customer_id': 298,
#   'Time left in queue': 60.72830747435404,
#   'Arrival time': 876,
#   'Exit time': 1327.2842446552809},
#  {'Customer_id': 299,
#   'Time left in queue': 182.42600893877568,
#   'Arrival time': 877,
#   'Exit time': 964.1716022612778},
#  {'Customer_id': 300,
#   'Time left in queue': 0,
#   'Arrival time': 879,
#   'Exit time': 944},
#  {'Customer_id': 301,
#   'Time left in queue': 30.403789589823987,
#   'Arrival time': 880,
#   'Exit time': 1088.3761207049047},
#  {'Customer_id': 302,
#   'Time left in queue': 53.18071401313034,
#   'Arrival time': 881,
#   'Exit time': 1294.8531202118265},
#  {'Customer_id': 303,
#   'Time left in queue': 36.956276300405904,
#   'Arrival time': 885,
#   'Exit time': 1141.6505938405685},
#  {'Customer_id': 304,
#   'Time left in queue': 80.13243099844306,
#   'Arrival time': 886,
#   'Exit time': 1062.4232684083263},
#  {'Customer_id': 305,
#   'Time left in queue': 37.927526067295545,
#   'Arrival time': 887,
#   'Exit time': 978.926806176231},
#  {'Customer_id': 306,
#   'Time left in queue': 0,
#   'Arrival time': 888,
#   'Exit time': 920},
#  {'Customer_id': 307,
#   'Time left in queue': 57.606977631045936,
#   'Arrival time': 895,
#   'Exit time': 1152.7646807146357},
#  {'Customer_id': 308,
#   'Time left in queue': 271.0209096286028,
#   'Arrival time': 901,
#   'Exit time': 1486.765212773591},
#  {'Customer_id': 309,
#   'Time left in queue': 204.9653739669668,
#   'Arrival time': 902,
#   'Exit time': 1045.9280530145536},
#  {'Customer_id': 310,
#   'Time left in queue': 174.54075595495755,
#   'Arrival time': 903,
#   'Exit time': 1278.5811543095547},
#  {'Customer_id': 311,
#   'Time left in queue': 265.19730595863115,
#   'Arrival time': 912,
#   'Exit time': 1096.7108957263924},
#  {'Customer_id': 312,
#   'Time left in queue': 67.38488899656926,
#   'Arrival time': 913,
#   'Exit time': 1122.3410707341716},
#  {'Customer_id': 313,
#   'Time left in queue': 0,
#   'Arrival time': 916,
#   'Exit time': 983},
#  {'Customer_id': 314,
#   'Time left in queue': 43.07156560679351,
#   'Arrival time': 920,
#   'Exit time': 1092.987705876929},
#  {'Customer_id': 315,
#   'Time left in queue': 212.76375028537933,
#   'Arrival time': 924,
#   'Exit time': 1019.2506827742308},
#  {'Customer_id': 316,
#   'Time left in queue': 127.99413937513012,
#   'Arrival time': 925,
#   'Exit time': 1233.385391887516},
#  {'Customer_id': 317,
#   'Time left in queue': 169.43549313392725,
#   'Arrival time': 926,
#   'Exit time': 1214.9994492421133},
#  {'Customer_id': 318,
#   'Time left in queue': 38.28456358882025,
#   'Arrival time': 927,
#   'Exit time': 1062.2025627357034},
#  {'Customer_id': 319,
#   'Time left in queue': 0,
#   'Arrival time': 928,
#   'Exit time': 953},
#  {'Customer_id': 320,
#   'Time left in queue': 176.22947505939226,
#   'Arrival time': 929,
#   'Exit time': 1054.3221743851975},
#  {'Customer_id': 321,
#   'Time left in queue': 92.26359398749571,
#   'Arrival time': 930,
#   'Exit time': 1067.075191026377},
#  {'Customer_id': 322,
#   'Time left in queue': 0,
#   'Arrival time': 931,
#   'Exit time': 1022},
#  {'Customer_id': 323,
#   'Time left in queue': 160.38025428643283,
#   'Arrival time': 936,
#   'Exit time': 1308.3127889256514},
#  {'Customer_id': 324,
#   'Time left in queue': 0,
#   'Arrival time': 937,
#   'Exit time': 962},
#  {'Customer_id': 325,
#   'Time left in queue': 131.65674462765386,
#   'Arrival time': 938,
#   'Exit time': 1327.026632779668},
#  {'Customer_id': 326,
#   'Time left in queue': 0,
#   'Arrival time': 940,
#   'Exit time': 957},
#  {'Customer_id': 327,
#   'Time left in queue': 13.319504987332948,
#   'Arrival time': 942,
#   'Exit time': 1080.9631193494806},
#  {'Customer_id': 328,
#   'Time left in queue': 182.85929550910578,
#   'Arrival time': 948,
#   'Exit time': 1192.8987528785294},
#  {'Customer_id': 329,
#   'Time left in queue': 98.96013702925706,
#   'Arrival time': 950,
#   'Exit time': 1083.899593754648},
#  {'Customer_id': 330,
#   'Time left in queue': 0,
#   'Arrival time': 951,
#   'Exit time': 1001},
#  {'Customer_id': 331,
#   'Time left in queue': 0,
#   'Arrival time': 957,
#   'Exit time': 994},
#  {'Customer_id': 332,
#   'Time left in queue': 0,
#   'Arrival time': 959,
#   'Exit time': 1038},
#  {'Customer_id': 333,
#   'Time left in queue': 0,
#   'Arrival time': 960,
#   'Exit time': 1024},
#  {'Customer_id': 334,
#   'Time left in queue': 166.4757688683638,
#   'Arrival time': 962,
#   'Exit time': 1358.5460526848913},
#  {'Customer_id': 335,
#   'Time left in queue': 7.918043998469017,
#   'Arrival time': 963,
#   'Exit time': 1259.0124106306491},
#  {'Customer_id': 336,
#   'Time left in queue': 92.05615768642895,
#   'Arrival time': 964,
#   'Exit time': 1246.3353855090927},
#  {'Customer_id': 337,
#   'Time left in queue': 0,
#   'Arrival time': 966,
#   'Exit time': 1022},
#  {'Customer_id': 338,
#   'Time left in queue': 248.7359625379101,
#   'Arrival time': 968,
#   'Exit time': 1137.7637809844657},
#  {'Customer_id': 339,
#   'Time left in queue': 217.63965950107547,
#   'Arrival time': 970,
#   'Exit time': 1140.218739398873},
#  {'Customer_id': 340,
#   'Time left in queue': 0,
#   'Arrival time': 971,
#   'Exit time': 994},
#  {'Customer_id': 341,
#   'Time left in queue': 118.64280927540952,
#   'Arrival time': 972,
#   'Exit time': 1077.8156330128388},
#  {'Customer_id': 342,
#   'Time left in queue': 150.52285592027013,
#   'Arrival time': 975,
#   'Exit time': 1079.9219665325816},
#  {'Customer_id': 343,
#   'Time left in queue': 211.421715551817,
#   'Arrival time': 978,
#   'Exit time': 1386.3298878993282},
#  {'Customer_id': 344,
#   'Time left in queue': 229.06026449177523,
#   'Arrival time': 979,
#   'Exit time': 1250.004383984789},
#  {'Customer_id': 345,
#   'Time left in queue': 0,
#   'Arrival time': 980,
#   'Exit time': 1001},
#  {'Customer_id': 346,
#   'Time left in queue': 0,
#   'Arrival time': 984,
#   'Exit time': 1005},
#  {'Customer_id': 347,
#   'Time left in queue': 220.9296042552548,
#   'Arrival time': 987,
#   'Exit time': 1195.7801387753266},
#  {'Customer_id': 348,
#   'Time left in queue': 231.4186150596064,
#   'Arrival time': 988,
#   'Exit time': 1133.1764967178706},
#  {'Customer_id': 349,
#   'Time left in queue': 0,
#   'Arrival time': 991,
#   'Exit time': 1061},
#  {'Customer_id': 350,
#   'Time left in queue': 23.676711237617013,
#   'Arrival time': 993,
#   'Exit time': 1267.8405560664446},
#  {'Customer_id': 351,
#   'Time left in queue': 223.04631566194257,
#   'Arrival time': 995,
#   'Exit time': 1210.2476106728097},
#  {'Customer_id': 352,
#   'Time left in queue': 52.720029753629575,
#   'Arrival time': 1000,
#   'Exit time': 1335.6252105156866},
#  {'Customer_id': 353,
#   'Time left in queue': 91.6805925487931,
#   'Arrival time': 1008,
#   'Exit time': 1227.9446248318495},
#  {'Customer_id': 354,
#   'Time left in queue': 140.25947647433998,
#   'Arrival time': 1009,
#   'Exit time': 1113.2752904797383},
#  {'Customer_id': 355,
#   'Time left in queue': 51.8845833225798,
#   'Arrival time': 1013,
#   'Exit time': 1326.4278320123944},
#  {'Customer_id': 356,
#   'Time left in queue': 118.65627444494163,
#   'Arrival time': 1014,
#   'Exit time': 1658.4532651638265},
#  {'Customer_id': 357,
#   'Time left in queue': 9.018570334633225,
#   'Arrival time': 1018,
#   'Exit time': 1238.3988719503104},
#  {'Customer_id': 358,
#   'Time left in queue': 0,
#   'Arrival time': 1026,
#   'Exit time': 1120},
#  {'Customer_id': 359,
#   'Time left in queue': 0,
#   'Arrival time': 1027,
#   'Exit time': 1054},
#  {'Customer_id': 360,
#   'Time left in queue': 233.69612449004916,
#   'Arrival time': 1028,
#   'Exit time': 1200.552512956746},
#  {'Customer_id': 361,
#   'Time left in queue': 33.77446108800086,
#   'Arrival time': 1031,
#   'Exit time': 1349.8124965313928},
#  {'Customer_id': 362,
#   'Time left in queue': 0,
#   'Arrival time': 1037,
#   'Exit time': 1102},
#  {'Customer_id': 363,
#   'Time left in queue': 107.6060127065081,
#   'Arrival time': 1040,
#   'Exit time': 1554.252094817094},
#  {'Customer_id': 364,
#   'Time left in queue': 30.98767760633129,
#   'Arrival time': 1047,
#   'Exit time': 1177.695584810955},
#  {'Customer_id': 365,
#   'Time left in queue': 0,
#   'Arrival time': 1050,
#   'Exit time': 1109},
#  {'Customer_id': 366,
#   'Time left in queue': 58.27339786827591,
#   'Arrival time': 1052,
#   'Exit time': 1170.6136962221067},
#  {'Customer_id': 367,
#   'Time left in queue': 0,
#   'Arrival time': 1054,
#   'Exit time': 1121},
#  {'Customer_id': 368,
#   'Time left in queue': 43.45138788862252,
#   'Arrival time': 1057,
#   'Exit time': 1577.862463295427},
#  {'Customer_id': 369,
#   'Time left in queue': 53.062483714045925,
#   'Arrival time': 1058,
#   'Exit time': 1187.738272866896},
#  {'Customer_id': 370,
#   'Time left in queue': 129.5711954430839,
#   'Arrival time': 1059,
#   'Exit time': 1297.0640958952215},
#  {'Customer_id': 371,
#   'Time left in queue': 52.06744325548999,
#   'Arrival time': 1063,
#   'Exit time': 1291.9329249919465},
#  {'Customer_id': 372,
#   'Time left in queue': 166.73953442067483,
#   'Arrival time': 1067,
#   'Exit time': 1265.6145089185834},
#  {'Customer_id': 373,
#   'Time left in queue': 77.18669903692987,
#   'Arrival time': 1069,
#   'Exit time': 1201.1660254582432},
#  {'Customer_id': 374,
#   'Time left in queue': 175.93601037757753,
#   'Arrival time': 1070,
#   'Exit time': 1238.00058629329},
#  {'Customer_id': 375,
#   'Time left in queue': 0,
#   'Arrival time': 1071,
#   'Exit time': 1142},
#  {'Customer_id': 376,
#   'Time left in queue': 125.12158163851456,
#   'Arrival time': 1072,
#   'Exit time': 1224.191840074624},
#  {'Customer_id': 377,
#   'Time left in queue': 215.0591061744115,
#   'Arrival time': 1073,
#   'Exit time': 1288.1058989988162},
#  {'Customer_id': 378,
#   'Time left in queue': 229.29423087134091,
#   'Arrival time': 1074,
#   'Exit time': 1603.4062316501186},
#  {'Customer_id': 379,
#   'Time left in queue': 0,
#   'Arrival time': 1081,
#   'Exit time': 1123},
#  {'Customer_id': 380,
#   'Time left in queue': 19.73250790186526,
#   'Arrival time': 1084,
#   'Exit time': 1276.4151965379986},
#  {'Customer_id': 381,
#   'Time left in queue': 132.2809492023458,
#   'Arrival time': 1094,
#   'Exit time': 1245.2426747469292},
#  {'Customer_id': 382,
#   'Time left in queue': 3.149180663697436,
#   'Arrival time': 1096,
#   'Exit time': 1341.8886965436955},
#  {'Customer_id': 383,
#   'Time left in queue': 0,
#   'Arrival time': 1098,
#   'Exit time': 1131},
#  {'Customer_id': 384,
#   'Time left in queue': 0,
#   'Arrival time': 1099,
#   'Exit time': 1111},
#  {'Customer_id': 385,
#   'Time left in queue': 210.46165234709088,
#   'Arrival time': 1102,
#   'Exit time': 1428.3531784252525},
#  {'Customer_id': 386,
#   'Time left in queue': 238.8172453961178,
#   'Arrival time': 1105,
#   'Exit time': 1220.518591217858},
#  {'Customer_id': 387,
#   'Time left in queue': 248.46126952687933,
#   'Arrival time': 1110,
#   'Exit time': 1556.141487420797},
#  {'Customer_id': 388,
#   'Time left in queue': 146.87688149921723,
#   'Arrival time': 1113,
#   'Exit time': 1368.8170067962621},
#  {'Customer_id': 389,
#   'Time left in queue': 0,
#   'Arrival time': 1118,
#   'Exit time': 1172},
#  {'Customer_id': 390,
#   'Time left in queue': 0,
#   'Arrival time': 1122,
#   'Exit time': 1126},
#  {'Customer_id': 391,
#   'Time left in queue': 108.80616146988132,
#   'Arrival time': 1126,
#   'Exit time': 1282.0299943644789},
#  {'Customer_id': 392,
#   'Time left in queue': 0,
#   'Arrival time': 1127,
#   'Exit time': 1198},
#  {'Customer_id': 393,
#   'Time left in queue': 0,
#   'Arrival time': 1132,
#   'Exit time': 1147},
#  {'Customer_id': 394,
#   'Time left in queue': 161.20340417822362,
#   'Arrival time': 1133,
#   'Exit time': 1606.147239708841},
#  {'Customer_id': 395,
#   'Time left in queue': 0,
#   'Arrival time': 1134,
#   'Exit time': 1188},
#  {'Customer_id': 396,
#   'Time left in queue': 147.46863419361785,
#   'Arrival time': 1136,
#   'Exit time': 1373.15203007043},
#  {'Customer_id': 397,
#   'Time left in queue': 0,
#   'Arrival time': 1138,
#   'Exit time': 1150},
#  {'Customer_id': 398,
#   'Time left in queue': 157.71086271364962,
#   'Arrival time': 1142,
#   'Exit time': 1496.7498007942831},
#  {'Customer_id': 399,
#   'Time left in queue': 256.93809258724747,
#   'Arrival time': 1144,
#   'Exit time': 1556.6273114203657},
#  {'Customer_id': 400,
#   'Time left in queue': 0,
#   'Arrival time': 1146,
#   'Exit time': 1212},
#  {'Customer_id': 401,
#   'Time left in queue': 0,
#   'Arrival time': 1147,
#   'Exit time': 1214},
#  {'Customer_id': 402,
#   'Time left in queue': 0,
#   'Arrival time': 1148,
#   'Exit time': 1169},
#  {'Customer_id': 403,
#   'Time left in queue': 70.51113128259612,
#   'Arrival time': 1149,
#   'Exit time': 1287.0827066983336},
#  {'Customer_id': 404,
#   'Time left in queue': 141.63237282230617,
#   'Arrival time': 1150,
#   'Exit time': 1312.806655789053},
#  {'Customer_id': 405,
# ...
#   'Exit time': 3257.022683782738},
#  {'Customer_id': 868,
#   'Time left in queue': 156.32229312495448,
#   'Arrival time': 2675,
#   'Exit time': 2794.810116794139},
#  {'Customer_id': 869,
#   'Time left in queue': 33.800602606861574,
#   'Arrival time': 2684,
#   'Exit time': 2816.9025745942718},
#  {'Customer_id': 870,
#   'Time left in queue': 0,
#   'Arrival time': 2685,
#   'Exit time': 2747},
#  {'Customer_id': 871,
#   'Time left in queue': 129.737460502998,
#   'Arrival time': 2692,
#   'Exit time': 2897.565310696057},
#  {'Customer_id': 872,
#   'Time left in queue': 68.90093911421286,
#   'Arrival time': 2696,
#   'Exit time': 4028.9869058197255},
#  {'Customer_id': 873,
#   'Time left in queue': 222.89514309246982,
#   'Arrival time': 2699,
#   'Exit time': 2908.291443301593},
#  {'Customer_id': 874,
#   'Time left in queue': 12.90282891431724,
#   'Arrival time': 2707,
#   'Exit time': 2952.3479083315506},
#  {'Customer_id': 875,
#   'Time left in queue': 83.26475269686338,
#   'Arrival time': 2719,
#   'Exit time': 2936.152988013816},
#  {'Customer_id': 876,
#   'Time left in queue': 26.547149906030157,
#   'Arrival time': 2725,
#   'Exit time': 2993.7775778929804},
#  {'Customer_id': 877,
#   'Time left in queue': 185.169592930464,
#   'Arrival time': 2726,
#   'Exit time': 2827.1968633739543},
#  {'Customer_id': 878,
#   'Time left in queue': 269.65818544125136,
#   'Arrival time': 2727,
#   'Exit time': 2958.7216616322057},
#  {'Customer_id': 879,
#   'Time left in queue': 40.07201862726498,
#   'Arrival time': 2734,
#   'Exit time': 2851.466545250523},
#  {'Customer_id': 880,
#   'Time left in queue': 145.0912572802055,
#   'Arrival time': 2735,
#   'Exit time': 2838.8074674278296},
#  {'Customer_id': 881,
#   'Time left in queue': 25.84703504154818,
#   'Arrival time': 2736,
#   'Exit time': 2892.490312373705},
#  {'Customer_id': 882,
#   'Time left in queue': 126.7943876981337,
#   'Arrival time': 2737,
#   'Exit time': 2838.749887903644},
#  {'Customer_id': 883,
#   'Time left in queue': 0,
#   'Arrival time': 2738,
#   'Exit time': 2807},
#  {'Customer_id': 884,
#   'Time left in queue': 0,
#   'Arrival time': 2741,
#   'Exit time': 2817},
#  {'Customer_id': 885,
#   'Time left in queue': 0,
#   'Arrival time': 2742,
#   'Exit time': 2755},
#  {'Customer_id': 886,
#   'Time left in queue': 254.48720436429096,
#   'Arrival time': 2759,
#   'Exit time': 2838.7269657129777},
#  {'Customer_id': 887,
#   'Time left in queue': 108.63886828142279,
#   'Arrival time': 2760,
#   'Exit time': 3205.2396937867707},
#  {'Customer_id': 888,
#   'Time left in queue': 144.63492544096854,
#   'Arrival time': 2771,
#   'Exit time': 2821.2799634144203},
#  {'Customer_id': 889,
#   'Time left in queue': 225.60564561210953,
#   'Arrival time': 2773,
#   'Exit time': 2865.9359497548044},
#  {'Customer_id': 890,
#   'Time left in queue': 106.65557812206731,
#   'Arrival time': 2774,
#   'Exit time': 3028.9439670598317},
#  {'Customer_id': 891,
#   'Time left in queue': 187.10641579496013,
#   'Arrival time': 2780,
#   'Exit time': 2935.1452506066053},
#  {'Customer_id': 892,
#   'Time left in queue': 24.388879017657487,
#   'Arrival time': 2787,
#   'Exit time': 3217.060903515176},
#  {'Customer_id': 893,
#   'Time left in queue': 18.990752992425598,
#   'Arrival time': 2790,
#   'Exit time': 2851.701534094543},
#  {'Customer_id': 894,
#   'Time left in queue': 0,
#   'Arrival time': 2793,
#   'Exit time': 2803},
#  {'Customer_id': 895,
#   'Time left in queue': 157.6444347999947,
#   'Arrival time': 2797,
#   'Exit time': 2974.295571411449},
#  {'Customer_id': 896,
#   'Time left in queue': 30.32554708164868,
#   'Arrival time': 2804,
#   'Exit time': 2957.798546198909},
#  {'Customer_id': 897,
#   'Time left in queue': 0,
#   'Arrival time': 2806,
#   'Exit time': 2825},
#  {'Customer_id': 898,
#   'Time left in queue': 283.71251753114717,
#   'Arrival time': 2807,
#   'Exit time': 2849.067384667794},
#  {'Customer_id': 899,
#   'Time left in queue': 5.240814262126946,
#   'Arrival time': 2815,
#   'Exit time': 2936.113794287343},
#  {'Customer_id': 900,
#   'Time left in queue': 125.9139734650719,
#   'Arrival time': 2816,
#   'Exit time': 2934.59296409031},
#  {'Customer_id': 901,
#   'Time left in queue': 222.2099572931139,
#   'Arrival time': 2819,
#   'Exit time': 3077.0469478375776},
#  {'Customer_id': 902,
#   'Time left in queue': 2.370062588304503,
#   'Arrival time': 2820,
#   'Exit time': 3197.9096451889827},
#  {'Customer_id': 903,
#   'Time left in queue': 137.69624216852282,
#   'Arrival time': 2821,
#   'Exit time': 2926.47133933656},
#  {'Customer_id': 904,
#   'Time left in queue': 187.40028354051566,
#   'Arrival time': 2822,
#   'Exit time': 3083.811313493697},
#  {'Customer_id': 905,
#   'Time left in queue': 193.4414904469865,
#   'Arrival time': 2827,
#   'Exit time': 2898.8962160532765},
#  {'Customer_id': 906,
#   'Time left in queue': 162.5038870350462,
#   'Arrival time': 2828,
#   'Exit time': 3004.334782006371},
#  {'Customer_id': 907,
#   'Time left in queue': 181.23677324378292,
#   'Arrival time': 2833,
#   'Exit time': 2986.363128568688},
#  {'Customer_id': 908,
#   'Time left in queue': 326.6415457381343,
#   'Arrival time': 2840,
#   'Exit time': 3256.5423494583333},
#  {'Customer_id': 909,
#   'Time left in queue': 102.95758624951458,
#   'Arrival time': 2841,
#   'Exit time': 3289.877824515474},
#  {'Customer_id': 910,
#   'Time left in queue': 287.4300887436881,
#   'Arrival time': 2845,
#   'Exit time': 2934.8364793666433},
#  {'Customer_id': 911,
#   'Time left in queue': 225.15490098445838,
#   'Arrival time': 2848,
#   'Exit time': 2939.1287326268293},
#  {'Customer_id': 912,
#   'Time left in queue': 148.92495647095203,
#   'Arrival time': 2850,
#   'Exit time': 3202.7680813066468},
#  {'Customer_id': 913,
#   'Time left in queue': 129.5498684379645,
#   'Arrival time': 2854,
#   'Exit time': 2961.3277457692025},
#  {'Customer_id': 914,
#   'Time left in queue': 193.8489192303625,
#   'Arrival time': 2855,
#   'Exit time': 2911.1900547355744},
#  {'Customer_id': 915,
#   'Time left in queue': 159.89110712565864,
#   'Arrival time': 2856,
#   'Exit time': 2940.9493784305328},
#  {'Customer_id': 916,
#   'Time left in queue': 140.92277246510454,
#   'Arrival time': 2857,
#   'Exit time': 2942.219150896579},
#  {'Customer_id': 917,
#   'Time left in queue': 167.69224710145298,
#   'Arrival time': 2858,
#   'Exit time': 2987.9053343216938},
#  {'Customer_id': 918,
#   'Time left in queue': 92.96282479897812,
#   'Arrival time': 2860,
#   'Exit time': 3293.7849754461663},
#  {'Customer_id': 919,
#   'Time left in queue': 161.28128397781205,
#   'Arrival time': 2863,
#   'Exit time': 3445.235963864551},
#  {'Customer_id': 920,
#   'Time left in queue': 271.2106139722125,
#   'Arrival time': 2864,
#   'Exit time': 3711.3808671949582},
#  {'Customer_id': 921,
#   'Time left in queue': 82.11080705406124,
#   'Arrival time': 2865,
#   'Exit time': 2985.5859155284256},
#  {'Customer_id': 922,
#   'Time left in queue': 252.05667113366957,
#   'Arrival time': 2866,
#   'Exit time': 3211.0596522976907},
#  {'Customer_id': 923,
#   'Time left in queue': 274.97064863214223,
#   'Arrival time': 2867,
#   'Exit time': 3156.253100816162},
#  {'Customer_id': 924,
#   'Time left in queue': 0,
#   'Arrival time': 2873,
#   'Exit time': 2917},
#  {'Customer_id': 925,
#   'Time left in queue': 127.21886293429077,
#   'Arrival time': 2874,
#   'Exit time': 3299.1356691919373},
#  {'Customer_id': 926,
#   'Time left in queue': 29.778253258038916,
#   'Arrival time': 2875,
#   'Exit time': 3585.5900435080284},
#  {'Customer_id': 927,
#   'Time left in queue': 137.5076812540921,
#   'Arrival time': 2877,
#   'Exit time': 2967.20486409144},
#  {'Customer_id': 928,
#   'Time left in queue': 261.5186147972228,
#   'Arrival time': 2881,
#   'Exit time': 3066.3684525919266},
#  {'Customer_id': 929,
#   'Time left in queue': 149.69652019207894,
#   'Arrival time': 2883,
#   'Exit time': 3051.835480986063},
#  {'Customer_id': 930,
#   'Time left in queue': 39.22931141987655,
#   'Arrival time': 2884,
#   'Exit time': 3029.5446979911},
#  {'Customer_id': 931,
#   'Time left in queue': 23.747478837388883,
#   'Arrival time': 2886,
#   'Exit time': 3295.709526348843},
#  {'Customer_id': 932,
#   'Time left in queue': 150.44029953400457,
#   'Arrival time': 2892,
#   'Exit time': 3119.3653997010783},
#  {'Customer_id': 933,
#   'Time left in queue': 221.73848163530135,
#   'Arrival time': 2893,
#   'Exit time': 2999.871660170322},
#  {'Customer_id': 934,
#   'Time left in queue': 48.82744606978997,
#   'Arrival time': 2894,
#   'Exit time': 3030.988290930728},
#  {'Customer_id': 935,
#   'Time left in queue': 118.7130797697246,
#   'Arrival time': 2895,
#   'Exit time': 3192.555802949035},
#  {'Customer_id': 936,
#   'Time left in queue': 74.91183155188867,
#   'Arrival time': 2897,
#   'Exit time': 3003.346459944109},
#  {'Customer_id': 937,
#   'Time left in queue': 0,
#   'Arrival time': 2900,
#   'Exit time': 2956},
#  {'Customer_id': 938,
#   'Time left in queue': 116.26559205980038,
#   'Arrival time': 2906,
#   'Exit time': 3062.380777587124},
#  {'Customer_id': 939,
#   'Time left in queue': 0,
#   'Arrival time': 2907,
#   'Exit time': 2967},
#  {'Customer_id': 940,
#   'Time left in queue': 237.38681950963644,
#   'Arrival time': 2908,
#   'Exit time': 3237.093594539079},
#  {'Customer_id': 941,
#   'Time left in queue': 46.26105602092849,
#   'Arrival time': 2909,
#   'Exit time': 3009.3237830133166},
#  {'Customer_id': 942,
#   'Time left in queue': 110.75161977097474,
#   'Arrival time': 2910,
#   'Exit time': 3306.7435965723143},
#  {'Customer_id': 943,
#   'Time left in queue': 249.52359557154705,
#   'Arrival time': 2911,
#   'Exit time': 3294.4077643915357},
#  {'Customer_id': 944,
#   'Time left in queue': 231.56238787653655,
#   'Arrival time': 2913,
#   'Exit time': 3337.6339958860353},
#  {'Customer_id': 945,
#   'Time left in queue': 122.13556867287122,
#   'Arrival time': 2916,
#   'Exit time': 3404.9324544818746},
#  {'Customer_id': 946,
#   'Time left in queue': 41.78215889739043,
#   'Arrival time': 2917,
#   'Exit time': 3240.6806173896885},
#  {'Customer_id': 947,
#   'Time left in queue': 100.78772423899582,
#   'Arrival time': 2920,
#   'Exit time': 3246.573794333032},
#  {'Customer_id': 948,
#   'Time left in queue': 10.52152616211356,
#   'Arrival time': 2921,
#   'Exit time': 3135.73709833993},
#  {'Customer_id': 949,
#   'Time left in queue': 142.61944590080623,
#   'Arrival time': 2922,
#   'Exit time': 3116.1227913016123},
#  {'Customer_id': 950,
#   'Time left in queue': 106.50576159285461,
#   'Arrival time': 2928,
#   'Exit time': 3036.0963159004004},
#  {'Customer_id': 951,
#   'Time left in queue': 0,
#   'Arrival time': 2929,
#   'Exit time': 2950},
#  {'Customer_id': 952,
#   'Time left in queue': 117.85614796673022,
#   'Arrival time': 2930,
#   'Exit time': 3167.9544890427587},
#  {'Customer_id': 953,
#   'Time left in queue': 56.20446977505131,
#   'Arrival time': 2951,
#   'Exit time': 3045.2529955596688},
#  {'Customer_id': 954,
#   'Time left in queue': 29.696404795980328,
#   'Arrival time': 2955,
#   'Exit time': 3484.5064302875803},
#  {'Customer_id': 955,
#   'Time left in queue': 0,
#   'Arrival time': 2958,
#   'Exit time': 3014},
#  {'Customer_id': 956,
#   'Time left in queue': 236.01622830021978,
#   'Arrival time': 2959,
#   'Exit time': 3752.168197050008},
#  {'Customer_id': 957,
#   'Time left in queue': 170.70926704432065,
#   'Arrival time': 2965,
#   'Exit time': 3040.1233513146744},
#  {'Customer_id': 958,
#   'Time left in queue': 0,
#   'Arrival time': 2967,
#   'Exit time': 2982},
#  {'Customer_id': 959,
#   'Time left in queue': 0,
#   'Arrival time': 2970,
#   'Exit time': 2990},
#  {'Customer_id': 960,
#   'Time left in queue': 210.66528369506403,
#   'Arrival time': 2974,
#   'Exit time': 3044.005757586653},
#  {'Customer_id': 961,
#   'Time left in queue': 191.48849991623683,
#   'Arrival time': 2975,
#   'Exit time': 3086.004891240841},
#  {'Customer_id': 962,
#   'Time left in queue': 0,
#   'Arrival time': 2977,
#   'Exit time': 2981},
#  {'Customer_id': 963,
#   'Time left in queue': 126.53772910837506,
#   'Arrival time': 2979,
#   'Exit time': 3176.4790117523744},
#  {'Customer_id': 964,
#   'Time left in queue': 117.21525679506453,
#   'Arrival time': 2984,
#   'Exit time': 3238.1234144409555},
#  {'Customer_id': 965,
#   'Time left in queue': 0,
#   'Arrival time': 2987,
#   'Exit time': 3059},
#  {'Customer_id': 966,
#   'Time left in queue': 0,
#   'Arrival time': 2988,
#   'Exit time': 3060},
#  {'Customer_id': 967,
#   'Time left in queue': 134.74542813484243,
#   'Arrival time': 2989,
#   'Exit time': 3093.0677241553412},
#  {'Customer_id': 968,
#   'Time left in queue': 252.6009856165997,
#   'Arrival time': 2994,
#   'Exit time': 3179.2837324561465},
#  {'Customer_id': 969,
#   'Time left in queue': 33.25359136822644,
#   'Arrival time': 2995,
#   'Exit time': 3234.0750816611435},
#  {'Customer_id': 970,
#   'Time left in queue': 257.869527186628,
#   'Arrival time': 2998,
#   'Exit time': 3156.811466483928},
#  {'Customer_id': 971,
#   'Time left in queue': 235.9717381862033,
#   'Arrival time': 2999,
#   'Exit time': 3522.7004801498615},
#  {'Customer_id': 972,
#   'Time left in queue': 220.0008123570497,
#   'Arrival time': 3001,
#   'Exit time': 3673.960511607767},
#  {'Customer_id': 973,
#   'Time left in queue': 0,
#   'Arrival time': 3003,
#   'Exit time': 3005},
#  {'Customer_id': 974,
#   'Time left in queue': 68.413446772235,
#   'Arrival time': 3015,
#   'Exit time': 3172.6784896109884},
#  {'Customer_id': 975,
#   'Time left in queue': 0,
#   'Arrival time': 3016,
#   'Exit time': 3071},
#  {'Customer_id': 976,
#   'Time left in queue': 0,
#   'Arrival time': 3018,
#   'Exit time': 3059},
#  {'Customer_id': 977,
#   'Time left in queue': 0,
#   'Arrival time': 3020,
#   'Exit time': 3091},
#  {'Customer_id': 978,
#   'Time left in queue': 260.7806364353298,
#   'Arrival time': 3029,
#   'Exit time': 3363.393881854096},
#  {'Customer_id': 979,
#   'Time left in queue': 0,
#   'Arrival time': 3038,
#   'Exit time': 3062},
#  {'Customer_id': 980,
#   'Time left in queue': 122.64064785546907,
#   'Arrival time': 3039,
#   'Exit time': 3212.9045885494525},
#  {'Customer_id': 981,
#   'Time left in queue': 113.29753174798839,
#   'Arrival time': 3042,
#   'Exit time': 3358.9136675255277},
#  {'Customer_id': 982,
#   'Time left in queue': 102.25186003892347,
#   'Arrival time': 3047,
#   'Exit time': 3400.2704647400383},
#  {'Customer_id': 983,
#   'Time left in queue': 56.38324916717718,
#   'Arrival time': 3050,
#   'Exit time': 3651.0932414611816},
#  {'Customer_id': 984,
#   'Time left in queue': 182.2793123137352,
#   'Arrival time': 3051,
#   'Exit time': 3152.3235481069473},
#  {'Customer_id': 985,
#   'Time left in queue': 208.5798948478526,
#   'Arrival time': 3053,
#   'Exit time': 3273.4727328722165},
#  {'Customer_id': 986,
#   'Time left in queue': 121.40466710055898,
#   'Arrival time': 3056,
#   'Exit time': 3354.2149968970684},
#  {'Customer_id': 987,
#   'Time left in queue': 158.53916070080567,
#   'Arrival time': 3057,
#   'Exit time': 3240.921297622429},
#  {'Customer_id': 988,
#   'Time left in queue': 181.30180744111334,
#   'Arrival time': 3062,
#   'Exit time': 3169.8836162183393},
#  {'Customer_id': 989,
#   'Time left in queue': 145.98481635358863,
#   'Arrival time': 3063,
#   'Exit time': 3288.4798019690716},
#  {'Customer_id': 990,
#   'Time left in queue': 0,
#   'Arrival time': 3065,
#   'Exit time': 3086},
#  {'Customer_id': 991,
#   'Time left in queue': 148.2315291894642,
#   'Arrival time': 3066,
#   'Exit time': 3307.641374597209},
#  {'Customer_id': 992,
#   'Time left in queue': 219.17227219811252,
#   'Arrival time': 3070,
#   'Exit time': 3286.398561074436},
#  {'Customer_id': 993,
#   'Time left in queue': 252.9691832038992,
#   'Arrival time': 3071,
#   'Exit time': 3252.281770039052},
#  {'Customer_id': 994,
#   'Time left in queue': 125.42949250984591,
#   'Arrival time': 3074,
#   'Exit time': 3219.904487986938},
#  {'Customer_id': 995,
#   'Time left in queue': 186.06785489584337,
#   'Arrival time': 3075,
#   'Exit time': 3272.61164658307},
#  {'Customer_id': 996,
#   'Time left in queue': 51.72191177071667,
#   'Arrival time': 3082,
#   'Exit time': 3250.3516855907455},
#  {'Customer_id': 997,
#   'Time left in queue': 0,
#   'Arrival time': 3083,
#   'Exit time': 3164},
#  {'Customer_id': 998,
#   'Time left in queue': 173.33792239100023,
#   'Arrival time': 3086,
#   'Exit time': 3822.6171742800298},
#  {'Customer_id': 999,
#   'Time left in queue': 115.78336869786065,
#   'Arrival time': 3098,
#   'Exit time': 3686.7619702731636},
#  {'Customer_id': 1000,
#   'Time left in queue': 8.81504121471994,
#   'Arrival time': 3100,
#   'Exit time': 3370.5173881407004},
#  ...]
